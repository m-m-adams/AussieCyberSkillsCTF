# %%
import gmpy
N= ...

e= 3

c= 

# %%
c_big = gmpy.mpz(c)
m=int(c_big.root(3)[0])
m
# Out:
# 50937517511014139292496019951254165280192374749027520085833961767774599040163673309000829

# %%
m.to_bytes(512,'big').decode('utf8')
# Out:
# '\
# ...
